# %%
import os
import random
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Embedding, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import nltk

nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
# Out:
# WARNING:tensorflow:From C:\Users\lol19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lol19\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lol19\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lol19\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Global settings
def estimate_accuracy(X_test, y_test, y_pred):
    loss, accuracy = model.evaluate(X_test, y_test, verbose = 0)
    print(f"\nTest loss:          {loss}")
    print(f"Test accuracy:      {accuracy}\n")

    # Convert probabilities to class labels
    y_pred_labels = np.argmax(y_pred, axis = 1)
    print(classification_report(y_test, y_pred_labels))
    print(confusion_matrix(y_test, y_pred_labels))


random_state = 2291
pd.set_option("display.max_colwidth", 200)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # Disable warnings
random.seed(random_state)
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %%
# RECURRENT NEURAL NETWORK (RNN)
# Load dataset:     https://www.kaggle.com/datasets/lakshmi25npathi/images
file_dataset = "input/Youtube02-KatyPerry.csv"
data = pd.read_csv(file_dataset, encoding = "latin-1")
data = data.drop("COMMENT_ID", axis = 1)
data = data.drop("AUTHOR", axis = 1)
data = data.drop("DATE", axis = 1)
feature_names = {
    "CONTENT": "Content",
    "CLASS": "Category"
}
data = data.rename(columns = feature_names)
data.info()
display(data)
unique_vals = data["Category"].unique()
print(unique_vals)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Content   350 non-null    object
#  1   Category  350 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.6+ KB
#                                                                                                                                                                                                      Content  \
# 0                                                                           i love this so much. AND also I Generate Free Leads on Auto Pilot &amp; You Can  Too! http://www.MyLeaderGate.com/moretrafficï»¿
# 1                                          http://www.billboard.com/articles/columns/pop-shop/6174122/fan-army-face-off-round-3 Vote for SONES please....we're against vips....please help us.. &gt;.&lt;ï»¿
# 2    Hey guys! Please join me in my fight to help abused/mistreated animals! All  fund will go to helping pay for vet bills/and or helping them find homes! I  will place an extra emphasis on helping di...
# 3                                                                                                                                                     http://psnboss.com/?ref=2tGgp3pV6L this is the songï»¿
# 4                                                                                                                         Hey everyone. Watch this trailer!!!!!!!!  http://believemefilm.com?hlr=h2hQBUVBï»¿
# ..                                                                                                                                                                                                       ...
# 345                                                                                                        This song means so much to me thank you  soooooooooooooooooooooooooooooooooooooooo much:-) Xxxï»¿
# 346                                                                                                                                                                                                 &lt;3ï»¿
# 347  KATY PERRY, I AM THE "DÃCIO CABELO", "DECIO HAIR". I AM 60 YEARS OF AGE. I  DON"T HAVE FAMILY. I"M SINGLE. ALONE. HOMELESS. I WAS AN ALCOHOLIC: 15 AT  THE AGE OF 46. I AM AN INVISIBLE COMPOSER. M...
# 348    Honestly speaking except taylor swift and adele i don't lile any of the  modern day singers. But i must say whenever i hear this song i feel  goosebumps. Its quite inspiring!! Thanks miss Perry!ï»¿
# 349                                                                                                                                            who is going to reach the billion first : katy or taylor ?ï»¿
#
#      Category
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 345         0
# 346         0
# 347         1
# 348         0
# 349         0
#
# [350 rows x 2 columns]
# [1 0]

# %%
# Preprocess texts
def clean_text(text):
    tokens = word_tokenize(text)  # Split text into tokens

    # Remove punctuation, convert to lower case, clean stop words
    stop_words = stopwords.words("english")
    words = []
    for token in tokens:
        if token.isalpha():
            word = token.lower()
            if word not in stop_words:
                words.append(word)

    # Perform stemming
    stemmer = PorterStemmer()
    stemmed_words = []
    for word in words:
        stemmed_word = stemmer.stem(word)
        stemmed_words.append(stemmed_word)
    stemmed_text = " ".join(stemmed_words)

    return stemmed_text


data_before = data.copy()
data["Content"] = data["Content"].apply(clean_text)
max_length = data["Content"].apply(len).max()
display(data_before.head(6))
display(data.head(6))
# Out:
#                                                                                                                                                                                                    Content  \
# 0                                                                         i love this so much. AND also I Generate Free Leads on Auto Pilot &amp; You Can  Too! http://www.MyLeaderGate.com/moretrafficï»¿
# 1                                        http://www.billboard.com/articles/columns/pop-shop/6174122/fan-army-face-off-round-3 Vote for SONES please....we're against vips....please help us.. &gt;.&lt;ï»¿
# 2  Hey guys! Please join me in my fight to help abused/mistreated animals! All  fund will go to helping pay for vet bills/and or helping them find homes! I  will place an extra emphasis on helping di...
# 3                                                                                                                                                   http://psnboss.com/?ref=2tGgp3pV6L this is the songï»¿
# 4                                                                                                                       Hey everyone. Watch this trailer!!!!!!!!  http://believemefilm.com?hlr=h2hQBUVBï»¿
# 5                                          check out my rapping hope you guys like it  https://soundcloud.com/nereboy/call-of-the-lostproduce-by-atlastatlas-rapper-jkork  and follow and message me :)ï»¿
#
#    Category
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1
#                                                                                                                                                                 Content  \
# 0                                                                                                                    love much also gener free lead auto pilot amp http
# 1                                                                                                                        http vote sone pleas vip pleas help us gt lt ï
# 2  hey guy pleas join fight help anim fund go help pay vet help find home place extra emphasi help disabl anim one otherwis would put sleep anim organ donat pleas http
# 3                                                                                                                                                            http songï
# 4                                                                                                                                        hey everyon watch trailer http
# 5                                                                                                                          check rap hope guy like http follow messag ï
#
#    Category
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1

# %%
# Split dataset into training set and test set
X = data["Content"]
y = data["Category"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = random_state)

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts = X_train)
vocab_size = len(tokenizer.word_index) + 1
print(f"Vocabulary size:    {vocab_size}")
print(f"Max text length:    {max_length}\n")
# Out:
# Vocabulary size:    895
# Max text length:    320

# %%
# Convert texts to sequences of indexes. Then add padding
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
preprocessed_text = tokenizer.sequences_to_texts([X_train[0]])[0]
print("Text to integer sequences:\n"
      f"  (preprocessed) -> {preprocessed_text}\n"
      f"  (tokenized)    -> {X_train[0]}")
X_train = pad_sequences(X_train, maxlen = max_length)
X_test = pad_sequences(X_test, maxlen = max_length)
# Out:
# Text to integer sequences:
#   (preprocessed) -> hey guy go check video name growtopia stori ï
#   (tokenized)    -> [17, 13, 21, 11, 5, 185, 308, 309, 1]

# %%
# Create RNN model
model = Sequential(
    [
        Embedding(input_dim = vocab_size, input_length = max_length, output_dim = 32),
        LSTM(units = 64, return_sequences = True),
        Dropout(0.2),
        LSTM(units = 64),
        Dropout(0.3),
        Dense(units = len(unique_vals), activation = "softmax")
    ]
)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\lol19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 320, 32)           28640
#
#  lstm (LSTM)                 (None, 320, 64)           24832
#
#  dropout (Dropout)           (None, 320, 64)           0
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 86626 (338.38 KB)
# Trainable params: 86626 (338.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile and fit RNN
model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)
model.fit(X_train, y_train, batch_size = 128, epochs = 35, validation_split = 0.1)
y_pred = model.predict(X_test)
estimate_accuracy(X_test, y_test, y_pred)
# Out:
# WARNING:tensorflow:From C:\Users\lol19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/35
# WARNING:tensorflow:From C:\Users\lol19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\lol19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2/2 [==============================] - 5s 2s/step - loss: 0.6937 - accuracy: 0.4683 - val_loss: 0.6945 - val_accuracy: 0.4286
# Epoch 2/35
# 2/2 [==============================] - 2s 910ms/step - loss: 0.6907 - accuracy: 0.5278 - val_loss: 0.6939 - val_accuracy: 0.4286
# Epoch 3/35
# 2/2 [==============================] - 2s 875ms/step - loss: 0.6882 - accuracy: 0.5278 - val_loss: 0.6937 - val_accuracy: 0.4286
# Epoch 4/35
# 2/2 [==============================] - 2s 938ms/step - loss: 0.6848 - accuracy: 0.5278 - val_loss: 0.6912 - val_accuracy: 0.4286
# Epoch 5/35
# 2/2 [==============================] - 2s 838ms/step - loss: 0.6805 - accuracy: 0.5278 - val_loss: 0.6873 - val_accuracy: 0.4286
# Epoch 6/35
# 2/2 [==============================] - 1s 808ms/step - loss: 0.6729 - accuracy: 0.5397 - val_loss: 0.6785 - val_accuracy: 0.7143
# Epoch 7/35
# 2/2 [==============================] - 1s 855ms/step - loss: 0.6588 - accuracy: 0.7024 - val_loss: 0.6680 - val_accuracy: 0.8214
# Epoch 8/35
# 2/2 [==============================] - 1s 812ms/step - loss: 0.6397 - accuracy: 0.7262 - val_loss: 0.6567 - val_accuracy: 0.7143
# Epoch 9/35
# 2/2 [==============================] - 1s 799ms/step - loss: 0.6178 - accuracy: 0.6944 - val_loss: 0.6811 - val_accuracy: 0.7143
# Epoch 10/35
# 2/2 [==============================] - 1s 825ms/step - loss: 0.5939 - accuracy: 0.6746 - val_loss: 0.7384 - val_accuracy: 0.7500
# Epoch 11/35
# 2/2 [==============================] - 1s 855ms/step - loss: 0.5614 - accuracy: 0.6706 - val_loss: 0.8358 - val_accuracy: 0.8571
# Epoch 12/35
# 2/2 [==============================] - 1s 815ms/step - loss: 0.5342 - accuracy: 0.7778 - val_loss: 0.8572 - val_accuracy: 0.6786
# Epoch 13/35
# 2/2 [==============================] - 2s 844ms/step - loss: 0.5091 - accuracy: 0.7500 - val_loss: 0.9753 - val_accuracy: 0.8929
# Epoch 14/35
# 2/2 [==============================] - 2s 928ms/step - loss: 0.4750 - accuracy: 0.8690 - val_loss: 1.0234 - val_accuracy: 0.8571
# Epoch 15/35
# 2/2 [==============================] - 2s 948ms/step - loss: 0.4452 - accuracy: 0.8373 - val_loss: 1.0713 - val_accuracy: 0.8214
# Epoch 16/35
# 2/2 [==============================] - 2s 862ms/step - loss: 0.4096 - accuracy: 0.8849 - val_loss: 1.0992 - val_accuracy: 0.7857
# Epoch 17/35
# 2/2 [==============================] - 2s 875ms/step - loss: 0.3837 - accuracy: 0.8373 - val_loss: 1.1946 - val_accuracy: 0.7857
# Epoch 18/35
# 2/2 [==============================] - 2s 857ms/step - loss: 0.3571 - accuracy: 0.9087 - val_loss: 1.1252 - val_accuracy: 0.8214
# Epoch 19/35
# 2/2 [==============================] - 1s 859ms/step - loss: 0.3205 - accuracy: 0.9048 - val_loss: 1.1312 - val_accuracy: 0.8571
# Epoch 20/35
# 2/2 [==============================] - 1s 838ms/step - loss: 0.2881 - accuracy: 0.9365 - val_loss: 1.0857 - val_accuracy: 0.8214
# Epoch 21/35
# 2/2 [==============================] - 2s 1s/step - loss: 0.2662 - accuracy: 0.9008 - val_loss: 1.0634 - val_accuracy: 0.8214
# Epoch 22/35
# 2/2 [==============================] - 2s 978ms/step - loss: 0.2367 - accuracy: 0.9563 - val_loss: 1.0411 - val_accuracy: 0.8214
# Epoch 23/35
# 2/2 [==============================] - 2s 863ms/step - loss: 0.2171 - accuracy: 0.9643 - val_loss: 0.8783 - val_accuracy: 0.8214
# Epoch 24/35
# 2/2 [==============================] - 1s 839ms/step - loss: 0.1953 - accuracy: 0.9484 - val_loss: 0.9507 - val_accuracy: 0.8214
# Epoch 25/35
# 2/2 [==============================] - 2s 857ms/step - loss: 0.1854 - accuracy: 0.9167 - val_loss: 0.6454 - val_accuracy: 0.7857
# Epoch 26/35
# 2/2 [==============================] - 2s 852ms/step - loss: 0.1941 - accuracy: 0.8810 - val_loss: 0.6182 - val_accuracy: 0.7857
# Epoch 27/35
# 2/2 [==============================] - 1s 843ms/step - loss: 0.1713 - accuracy: 0.9127 - val_loss: 0.5831 - val_accuracy: 0.8214
# Epoch 28/35
# 2/2 [==============================] - 2s 861ms/step - loss: 0.1474 - accuracy: 0.9722 - val_loss: 0.5422 - val_accuracy: 0.7857
# Epoch 29/35
# 2/2 [==============================] - 2s 863ms/step - loss: 0.1386 - accuracy: 0.9802 - val_loss: 0.5004 - val_accuracy: 0.7857
# Epoch 30/35
# 2/2 [==============================] - 2s 854ms/step - loss: 0.1267 - accuracy: 0.9802 - val_loss: 0.4674 - val_accuracy: 0.7857
# Epoch 31/35
# 2/2 [==============================] - 2s 873ms/step - loss: 0.1227 - accuracy: 0.9683 - val_loss: 0.4379 - val_accuracy: 0.7857
# Epoch 32/35
# 2/2 [==============================] - 2s 888ms/step - loss: 0.1149 - accuracy: 0.9762 - val_loss: 0.4116 - val_accuracy: 0.7857
# Epoch 33/35
# 2/2 [==============================] - 2s 889ms/step - loss: 0.1105 - accuracy: 0.9643 - val_loss: 0.3946 - val_accuracy: 0.8214
# Epoch 34/35
# 2/2 [==============================] - 2s 870ms/step - loss: 0.0991 - accuracy: 0.9722 - val_loss: 0.3874 - val_accuracy: 0.8214
# Epoch 35/35
# 2/2 [==============================] - 2s 925ms/step - loss: 0.0876 - accuracy: 0.9802 - val_loss: 0.3900 - val_accuracy: 0.8214
# 3/3 [==============================] - 1s 56ms/step
#
# Test loss:          0.2910350263118744
# Test accuracy:      0.8714285492897034
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        40
#            1       0.86      0.83      0.85        30
#
#     accuracy                           0.87        70
#    macro avg       0.87      0.87      0.87        70
# weighted avg       0.87      0.87      0.87        70
#
# [[36  4]
#  [ 5 25]]
