# %%
import pandas as pd
import json
import pytumblr
from datetime import datetime as dt
from bs4 import BeautifulSoup

# %%
# Authenticate via Tumblr API
with open("credentials.json") as fin:
    credentials = json.load(fin)

CONSUMER_KEY = credentials["CONSUMER_KEY"]
CONSUMER_SECRET = credentials["CONSUMER_SECRET"]
OAUTH_TOKEN = credentials["OAUTH_TOKEN"]
OAUTH_SECRET = credentials["OAUTH_SECRET"]

client = pytumblr.TumblrRestClient(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_SECRET)

# %%
# Retrieve posts from Tumblr and create dataset
blog_name = "redglassbird"  # Source:   https://www.tumblr.com/redglassbird
num_posts = 1050  # Total number of posts
limit = 50  # Max number of posts that can be retrieved in a single request
list_posts = []
for i in range(num_posts // limit):
    posts = client.posts(blog_name, limit = limit)
    for post in posts["posts"]:
        # Parse Datetime
        datetime_str = post["date"]
        datetime = dt.strptime(datetime_str, "%Y-%m-%d %H:%M:%S %Z")

        # Parse HTML body as text
        html_body = post["body"]
        soup = BeautifulSoup(html_body, "html.parser")
        body = soup.get_text()

        dict_post = {
            "Blog": post["blog_name"],
            "Datetime": datetime,
            "URL": post["post_url"],
            "Title": post["title"],
            "Body": body
        }
        list_posts.append(dict_post)

# Save dataset as CSV
file_csv = f"tumblr-{blog_name}.csv"
df = pd.DataFrame(list_posts)
df.to_csv(file_csv, index = False)
print(f"Number of entries: {len(df)}\n")
df.info()
display(df)
# Out:
# Number of entries: 1050
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Blog      1050 non-null   object
#  1   Datetime  1050 non-null   datetime64[ns]
#  2   URL       1050 non-null   object
#  3   Title     1008 non-null   object
#  4   Body      1050 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 41.1+ KB
#               Blog            Datetime  \
# 0     redglassbird 2024-06-03 14:57:47
# 1     redglassbird 2024-06-03 02:54:21
# 2     redglassbird 2024-06-01 12:11:44
# 3     redglassbird 2024-05-26 12:06:26
# 4     redglassbird 2024-05-25 20:07:13
# ...            ...                 ...
# 1045  redglassbird 2023-10-30 17:18:57
# 1046  redglassbird 2023-10-20 03:17:09
# 1047  redglassbird 2023-10-19 17:15:58
# 1048  redglassbird 2023-10-16 22:43:19
# 1049  redglassbird 2023-10-12 19:14:43
#
#                                                     URL Title  \
# 0     https://www.tumblr.com/blog/view/redglassbird/...
# 1     https://www.tumblr.com/blog/view/redglassbird/...
# 2     https://www.tumblr.com/blog/view/redglassbird/...
# 3     https://www.tumblr.com/blog/view/redglassbird/...
# 4     https://www.tumblr.com/blog/view/redglassbird/...
# ...                                                 ...   ...
# 1045  https://www.tumblr.com/blog/view/redglassbird/...
# 1046  https://www.tumblr.com/blog/view/redglassbird/...
# 1047  https://www.tumblr.com/blog/view/redglassbird/...
# 1048  https://www.tumblr.com/blog/view/redglassbird/...
# 1049  https://www.tumblr.com/blog/view/redglassbird/...
#
#                                                    Body
# 0     abalidoth:veil-of-exordia:confusing Odysseus a...
# 1     hello sharks today I am asking for five billio...
# 2     mandyseley:i-am-an-adult-i-swear:Sometimes the...
# 3     I think orthodontists made up retainers to pic...
# 4     I take my whiskey neat (I dont drink) my coffe...
# ...                                                 ...
# 1045  i think there should be an IQ test but for ele...
# 1046  The whores persist (impression of myself when ...
# 1047  I think we should as a society utilize the fir...
# 1048  you’re telling me this salesman is selling sna...
# 1049  Meddlesome Monday.Troubling Tuesday.Weary Wedn...
#
# [1050 rows x 5 columns]
